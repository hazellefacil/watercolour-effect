# %%
# %run watercolour_effect_model.ipynb

from matplotlib import pyplot as plt
from IPython import display

# %%
inp, re = load('1.jpg')
plt.figure()
plt.imshow(inp/255)
plt.figure()
plt.imshow(re/255)

# %%
#test discriminator

image_shape = inp.shape
discriminator = Discriminator(image_shape)

disc_out = discriminator([inp, re], training=False)
plt.imshow(disc_out[0, ..., -1], vmin=-20, vmax=20, cmap='RdBu_r')
plt.colorbar()
